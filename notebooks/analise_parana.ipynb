# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt


unidade = r'C:\Users\Jhonatan Pires\Downloads\projeto unidades basicas de saude\data\u.csv'
df_unidade = pd.read_csv(unidade, decimal=',', sep=';')
df_unidade_limpo = df_unidade.dropna(subset=['LATITUDE', 'LONGITUDE'])

df_parana = df_unidade_limpo[df_unidade_limpo['UF'] == 41]
print(f"Total de UBS no Paraná: {len(df_parana)}")
df_parana.head()

mapa = folium.Map(location=[-24.7, -51.9], zoom_start=6)


for _, row in df_parana.dropna(subset=['LATITUDE', 'LONGITUDE']).head(500).iterrows():
    folium.CircleMarker(
        location=[row['LATITUDE'], row['LONGITUDE']],
        radius=2,
        color='blue',
        fill=True,
        fill_opacity=0.6
    ).add_to(mapa)

mapa
# Out:
# Total de UBS no Paraná: 2237
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt


unidade = r'C:\Users\Jhonatan Pires\Downloads\projeto unidades basicas de saude\data\u.csv'
df_unidade = pd.read_csv(unidade, decimal=',', sep=';')
df_unidade_limpo = df_unidade.dropna(subset=['LATITUDE', 'LONGITUDE'])

df_parana = df_unidade_limpo[df_unidade_limpo['UF'] == 41]
print(f"Total de UBS no Paraná: {len(df_parana)}")
df_parana.head()

ubs_por_municipio = df_parana['IBGE'].value_counts().head(10)

plt.figure(figsize=(10, 5))
ubs_por_municipio.plot(kind='barh', color='orange')
plt.title('Top 10 Municípios (por código IBGE) com mais UBS no Paraná')
plt.xlabel('Quantidade de UBS')
plt.gca().invert_yaxis()
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.tight_layout()
plt.show()
# Out:
# Total de UBS no Paraná: 2237
